# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
x = [20, 40, 60, 80, 100]

# v200_top1 = [0.40, 1.00, 1.07, 1.07, 1.35, 1.28]
# v200_top1_err = [0.39, 0.62, 0.64, 0.77, 0.89, 0.81]

# v200_top5 = [2.44, 4.43, 4.76, 5.40, 5.19, 5.07]
# v200_top5_err = [1.10, 1.33, 1.82, 1.90, 1.91, 1.86]

# v2 = [50.35, 58.22, 59.03, 58.71, 59.88, 60.75]
# v2_err = [2.92, 4.69, 5.06, 5.57, 5.73, 4.29]

# v4 = [25.14, 32.81, 33.08, 34.61, 34.00, 35.28]
# v4_err = [2.81, 4.15, 4.91, 5.68, 4.71, 5.13]

# v10 = [9.81, 14.58, 14.82, 16.31, 16.47, 16.65]
# v10_err = [2.17, 2.64, 3.56, 3.81, 3.86, 4.47]


v200_top1 = [19.05, 21.70, 23.95, 23.85, 26.60]
v200_top1_err = [1.27, 1.66, 1.92, 1.96, 1.76]

v200_top5 = [46.80, 50.90, 54.75, 55.65, 56.40]
v200_top5_err = [2.10, 1.95, 2.19, 2.12, 2.43]

v2 = [92.00, 93.40, 95.00, 95.10, 94.35]
v2_err = [2.92, 0.49, 0.88, 0.63, 0.39, 0.30]

v4 = [83.30, 84.70, 87.25, 85.75, 87.25]
v4_err = [0.98, 1.51, 0.99, 1.63, 1.18]

v10 = [67.55, 69.50, 72.90, 73.35, 74.85]
v10_err = [1.84, 1.70, 1.45, 2.06, 1.54]

# %%
light_orange = '#FED8B1'
sky_blue = '#87CEEB'

# %%
y = v200_top1
y_err = v200_top1_err

fig, ax = plt.subplots()
ax.errorbar(x, y, yerr=y_err, fmt='o-', color="orange", capsize=5)
ax.fill_between(x, np.array(y) - np.array(y_err), np.array(y) + np.array(y_err), color=light_orange, alpha=0.3)
ax.set_xlabel('Amount of T.EEG2 training data (%)', fontsize=20)
ax.set_ylabel('200-way Top1 Accuracy (%)', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)  

# ax.set_title('Accuracy vs. Amount of Training Data')
plt.show()

# %%
y = v200_top5
y_err = v200_top5_err

fig, ax = plt.subplots()
ax.errorbar(x, y, yerr=y_err, fmt='o-', color='orange', capsize=5)
ax.fill_between(x, np.array(y) - np.array(y_err), np.array(y) + np.array(y_err), color=light_orange, alpha=0.3)
ax.set_xlabel('Amount of T.EEG2 training data (%)', fontsize=20)
ax.set_ylabel('200-way Top5 Accuracy (%)', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)  
# ax.set_title('Accuracy vs. Amount of Training Data')
plt.show()

# %%
x = [0, 20, 40, 60, 80, 100]

v200_top1 = [0.40, 1.00, 1.07, 1.07, 1.35, 1.28]
v200_top1_err = [0.39, 0.62, 0.64, 0.77, 0.89, 0.81]

v200_top5 = [2.44, 4.43, 4.76, 5.40, 5.19, 5.07]
v200_top5_err = [1.10, 1.33, 1.82, 1.90, 1.91, 1.86]

v2 = [50.35, 58.22, 59.03, 58.71, 59.88, 60.75]
v2_err = [2.92, 4.69, 5.06, 5.57, 5.73, 4.29]

v4 = [25.14, 32.81, 33.08, 34.61, 34.00, 35.28]
v4_err = [2.81, 4.15, 4.91, 5.68, 4.71, 5.13]

v10 = [9.81, 14.58, 14.82, 16.31, 16.47, 16.65]
v10_err = [2.17, 2.64, 3.56, 3.81, 3.86, 4.47]

# %%
y = v200_top1
y_err = v200_top1_err

fig, ax = plt.subplots()
ax.errorbar(x, y, yerr=y_err, fmt='o-', color=sky_blue, capsize=5)
ax.fill_between(x, np.array(y) - np.array(y_err), np.array(y) + np.array(y_err), color='lightblue', alpha=0.3)
ax.set_xlabel('Amount of T.EEG1 training data (%)', fontsize=20)
ax.set_ylabel('200-way Top1 Accuracy (%)', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)  

# ax.set_title('Accuracy vs. Amount of Training Data')
plt.show()

# %%
y = v200_top5
y_err = v200_top1_err

fig, ax = plt.subplots()
ax.errorbar(x, y, yerr=y_err, fmt='o-', color=sky_blue, capsize=5)
ax.fill_between(x, np.array(y) - np.array(y_err), np.array(y) + np.array(y_err), color='lightblue', alpha=0.3)
ax.set_xlabel('Amount of T.EEG1 training data (%)', fontsize=20)
ax.set_ylabel('200-way Top5 Accuracy (%)', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)  

# ax.set_title('Accuracy vs. Amount of Training Data')
plt.show()
